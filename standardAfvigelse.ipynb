# %%
import numpy as np
import matplotlib.pyplot as plt
from scipy.stats import norm

# %%
RANDOM_SEED = 8927
rng = np.random.default_rng(RANDOM_SEED)

# %%
gennemsnit = 167.7
standard_afvigelse  =  10

x = np.arange(100, 246, 0.001)

plt.plot(x, norm.pdf(x, gennemsnit, standard_afvigelse));
